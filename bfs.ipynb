# %% [markdown]
# <a href="https://colab.research.google.com/github/aswanth13/AIML/blob/main/bfs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from collections import deque

def bfs(graph, start, goal):

    # Queue: (current_node, path)
    queue = deque([(start, [])])

    visited = set()

    while queue:

        node, path = queue.popleft()

        if node in visited:
            continue

        visited.add(node)
        path = path + [node]

        if node == goal:
            return path

        for neighbor in graph.get(node, []):
            if neighbor not in visited:
                queue.append((neighbor, path))

    return []


# Graph input
graph = {
    'A': ['B', 'C'],
    'B': ['D', 'E'],
    'C': ['F'],
    'D': [],
    'E': ['G'],
    'F': ['G'],
    'G': []
}

start = 'A'
goal = 'G'

path = bfs(graph, start, goal)

print("Path:", " -> ".join(path))
# Out:
# Path: A -> B -> E -> G
