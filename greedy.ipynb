# %% [markdown]
# <a href="https://colab.research.google.com/github/aswanth13/AIML/blob/main/greedy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import heapq

def greedy_best_first_search(graph, heuristic, start, goal):
    priority_queue = [(heuristic[start], start)]
    visited = set()
    parent = {start: None}

    while priority_queue:
        h, current = heapq.heappop(priority_queue)

        if current in visited:
            continue

        visited.add(current)
        print("Visiting:", current)

        if current == goal:
            path = []
            while current is not None:
                path.append(current)
                current = parent[current]

            return path[::-1]

        for neighbour in graph[current]:
            if neighbour not in visited:
                parent[neighbour] = current
                heapq.heappush(
                    priority_queue,
                    (heuristic[neighbour], neighbour)
                )

    return None


# Graph
graph = {
    'A': ['B', 'C'],
    'B': ['D', 'E'],
    'C': ['F'],
    'D': [],
    'E': ['G'],
    'F': ['G'],
    'G': []
}

# Heuristic values
heuristic = {
    'A': 6,
    'B': 4,
    'C': 5,
    'D': 7,
    'E': 2,
    'F': 3,
    'G': 0
}

start = 'A'
goal = 'G'

path = greedy_best_first_search(graph, heuristic, start, goal)

print("Path:", path)
# Out:
# Visiting: A
# Visiting: B
# Visiting: E
# Visiting: G
# Path: ['A', 'B', 'E', 'G']
